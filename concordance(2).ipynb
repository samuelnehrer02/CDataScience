# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: joblib in c:\users\nehre\miniconda3\envs\eeg_env\lib\site-packages (from nltk) (1.3.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.9.11-cp310-cp310-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/41.5 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 41.5/41.5 kB 505.0 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\nehre\miniconda3\envs\eeg_env\lib\site-packages (from nltk) (4.66.2)
# Requirement already satisfied: colorama in c:\users\nehre\miniconda3\envs\eeg_env\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.1/1.5 MB 3.6 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.4/1.5 MB 6.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 0.8/1.5 MB 7.5 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.4 MB/s eta 0:00:00
# Downloading regex-2024.9.11-cp310-cp310-win_amd64.whl (274 kB)
#    ---------------------------------------- 0.0/274.0 kB ? eta -:--:--
#    ---------------------------------------- 274.0/274.0 kB 8.5 MB/s eta 0:00:00
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.7 nltk-3.9.1 regex-2024.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\nehre\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('blake-poems.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# []

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 0

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "blood":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['   runs in blood down palace-walls.  ']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 1

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance = []
for i, val in enumerate(bible):
    if val == "water":
        concordance.append(str(' '.join(bible[i-5:i+5])))
print(concordance)
print(f"the length of the concordance IS: {len(concordance)}")
# Out:
# [" and i stain'd the water clear,  and i", 'glass: like shadows in the water like dreams of infants,']
# the length of the concordance IS: 2

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here
# and run the cell...
bible = nltk.corpus.gutenberg.raw('blake-poems.txt')
bible = bible.lower()
bible = bible.replace('\n', ' ')
bible = bible.split(' ')
concordance = []
for i, val in enumerate(bible):
    if val == "thee":
        concordance.append(str(' '.join(bible[i-5:i+5])))
print(concordance)
print(f"the length of the concordance IS: {len(concordance)}")
# Out:
# ['   "piper, sit thee down and write ', ' little lamb, who make thee    dost', 'who made thee,  gave thee life, and bid thee', 'gave thee life, and bid thee feed  by the', "o'er the mead;  gave thee clothing of delight, ", 'clothing, wolly, bright;  gave thee such a tender voice,', "happy sleep,  while o'er thee doth mother weep. ", ' sweet babe, once like thee  thy maker lay,', 'hum;  little wanderer, hie thee home!"   ', 'watery shore,  are given thee till the break of', 'manna: till summers heat melts thee beside the fountains and', 'cloud, and it shall tell thee why it glitters in', 'the virgin said, i charge thee to tell me why', 'away: then we shall seek thee but not find: ah', 'but a worm? i see thee like an infant wrapped', 'to answer, none to cherish thee with mothers smiles. ', 'my children, i have loved thee and i have given', 'thee and i have given thee a crown that none', 'enter my house, tis given thee to enter, and to']
# the length of the concordance IS: 19

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
books
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

book_length = []


for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    # continue:
    book = book.lower()
    book = book.replace('\n', ' ')
    book = book.split(' ')
    # remove .txt
    title = title.replace('.txt', '')
    # and print the length of the book
    print(f"the title: {title}", f"the length of the book is: {len(book)}")
    # push the length of the book to the list book_length
    book_length.append(len(book))

# print out the highest value from the list book_length, find its index, and print out the title of the book with the highest word count
print(f"the highest book length is: {max(book_length)}")

print(f"the title of the longest book is: {books[book_length.index(max(book_length))]}")
# Out:
# the title: austen-emma the length of the book is: 164457
# the title: austen-persuasion the length of the book is: 86270
# the title: austen-sense the length of the book is: 123514
# the title: bible-kjv the length of the book is: 848001
# the title: blake-poems the length of the book is: 8886
# the title: bryant-stories the length of the book is: 49404
# the title: burgess-busterbrown the length of the book is: 16305
# the title: carroll-alice the length of the book is: 28387
# the title: chesterton-ball the length of the book is: 86481
# the title: chesterton-brown the length of the book is: 80382
# the title: chesterton-thursday the length of the book is: 59297
# the title: edgeworth-parents the length of the book is: 177685
# the title: melville-moby_dick the length of the book is: 221023
# the title: milton-paradise the length of the book is: 91832
# the title: shakespeare-caesar the length of the book is: 23339
# the title: shakespeare-hamlet the length of the book is: 33477
# the title: shakespeare-macbeth the length of the book is: 20164
# the title: whitman-leaves the length of the book is: 138730
# the highest book length is: 848001
# the title of the longest book is: bible-kjv.txt

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

###### Done in a chunk above ######

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# starter code:

def analyze_corpus(corpus_name):
    book = nltk.corpus.gutenberg.raw(corpus_name)
    words = book.lower()
    words = words.replace('\n', ' ')
    words = words.split(' ')
    freq = nltk.FreqDist(words)
    freq.most_common(10)

    # print the most common word in the corpus
    print(f"The most common word in {corpus_name} is: {freq.most_common(1)[0][0]}")

    freq.plot(15, color='purple', title=f'Top 15 words in {corpus_name}')


# use the function to plot the top 15 words in every book in the corpus
analyze_corpus('austen-emma.txt')
# Out:
# The most common word in austen-emma.txt is:

# %%
analyze_corpus('melville-moby_dick.txt')
# Out:
# The most common word in melville-moby_dick.txt is: the
# ) missing from current font.vs\eeg_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.vs\eeg_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# list of stopwords

stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# %%
# starter code:

book = nltk.corpus.gutenberg.raw('austen-emma.txt')
words = book.lower()


# code to remove stopwords.
words = [word for word in words if word not in stopwords]

def analyze_corpus_without_stopwords(corpus_name):
    book = nltk.corpus.gutenberg.raw(corpus_name)
    words = book.lower()
    words = words.replace('\n', ' ')
    words = words.split(' ')
    words = [word for word in words if word not in stopwords]
    freq = nltk.FreqDist(words)
    freq.most_common(10)

    # print the most common word in the corpus
    print(f"The most common word in {corpus_name} is: {freq.most_common(1)[0][0]}")

    freq.plot(15, color='purple', title=f'Top 15 words in {corpus_name}')

analyze_corpus_without_stopwords('austen-emma.txt')
# Out:
# The most common word in austen-emma.txt is: mr.

# %%
analyze_corpus_without_stopwords('melville-moby_dick.txt')
# Out:
# The most common word in melville-moby_dick.txt is:
# ) missing from current font.vs\eeg_env\lib\site-packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from current font.vs\eeg_env\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
